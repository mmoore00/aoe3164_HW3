# %%
import sklearn
import numpy as np     
import seaborn as sns
import math

# Plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt

# Tick parameters
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size'] = 5
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['legend.fontsize'] = 15

# %%
#grain_size = [0.8476, 0.845, 9.4598, 19.3864, 18.1735, 20.8162, 21.273, 19.6352, 
#              27.6082, 40.3989, 49.4007]
#fit_cosine = [0.85, 9.13, 10.36, 12.24,  14.95, 16.96, 
#              19.24, 24.76, 31.87, 41.02, 46.54]
#time_hrs=[0.0, 0.01666667,0.033333333,0.08333333,0.25,0.5,1.0,4.0,16.0,64.0,128.0]

#numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0, *, device=None)
eff_c = np.linspace(0.5, 1.0, num=10)
T2s = (eff_c * 398.2081) + 300
p2 = 101.3 * (T2s / 300) ** 3.5

#s25 = 1004.5 * np.log(T25 / 24) - 287 * math.log(25 / 101.3)
#s101 = 1004.5 * np.log(T25 / 24) - 287 * math.log(101.3 / 101.3)
#s1000 = 1004.5 * np.log(T25 / 24) - 287 * math.log(1000 / 101.3)

plt.plot(eff_c, p2, '-')

plt.xlabel('$\eta_c$')
plt.ylabel('p [$kPa$]')

p1 = 101.3
T1 = 300
T2 = 698.2081
T2s_1 = T2s[0]
T2s_2 = T2s[len(T2s) - 1]
p2_1 = p1 * (T2s_1 / T1) ** 3.5
p2_2 = p1 * (T2s_2 / T1) ** 3.5

s_1 = 1004.5 * math.log(T2 / T1) - 287 * math.log(p2_1 / p1)
s_2 = 1004.5 * math.log(T2 / T1) - 287 * math.log(p2_2 / p1)
s_p1 = np.linspace(s_2, s_1, num = 10)
T = T1 * np.exp((s_p1 / 1004.5) - 287 / 1004.5 * math.log(p1 / p1))

p1p2_1 = np.linspace(T[0], T2, num = 10)
p1p2_2 = np.linspace(T[len(T) - 1], T2, num = 10)
s_1lin = np.linspace(s_1, s_1, num = 10)
s_2lin = np.linspace(s_2, s_2, num = 10)

s1s2 = np.linspace(s_2, s_1, num = 10)
T2T2 = np.linspace(T2, T2, num=10)

f, Tsplt = plt.subplots(1)
Tsplt.plot(s_p1, T, '-', label='p1 isobar')
Tsplt.plot(s_1, T2, 'o', label='$\eta_c$ = 0.5')
Tsplt.plot(s_2, T2, 'o', label='$\eta_c$ = 1.0')
Tsplt.plot(s_2lin, p1p2_1, '-')
Tsplt.plot(s_1lin, p1p2_2, '-')
Tsplt.plot(s1s2, T2T2, '-')

Tsplt.legend(loc='center')
Tsplt.set_xlim(-10, s_1 + 10)
Tsplt.set_xlabel('s - $s_{ref}$ [$J/kgK$]')
Tsplt.set_ylabel('T [$K$]')
# Out:
# Text(0, 0.5, 'T [$K$]')
