# %%
import sklearn
import numpy as np     
import seaborn as sns
import math

# Plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt

# Tick parameters
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size'] = 5
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['legend.fontsize'] = 15

# %%
#grain_size = [0.8476, 0.845, 9.4598, 19.3864, 18.1735, 20.8162, 21.273, 19.6352, 
#              27.6082, 40.3989, 49.4007]
#fit_cosine = [0.85, 9.13, 10.36, 12.24,  14.95, 16.96, 
#              19.24, 24.76, 31.87, 41.02, 46.54]
#time_hrs=[0.0, 0.01666667,0.033333333,0.08333333,0.25,0.5,1.0,4.0,16.0,64.0,128.0]

T2 = [1100, 1200, 1300]
u2 = [0, 0, 0]
p2 = [0, 0, 0]

for i in range(len(T2)):
    u2[i] = math.sqrt(2 * (1495411.213 - (1064.8 * T2[i] - (2.44 * 10 ** -1) * T2[i] ** 2 + (3.8023 * 10 ** -4) * T2[i] ** 3 - (1.999975 * 10 ** -7) * T2[i] ** 4 + (3.8654 * 10 ** -11) * T2[i] ** 5)))
    p2[i] = (0.2 * 10 ** 6) * math.exp((1064.8 * math.log(T2[i]) - (4.88 * 10 ** - 1) * T2[i] + (5.7035 * 10 ** -4) * T2[i] ** 2 - (2.6666 * 10 ** -7) * T2[i] ** 3 + (4.83175 * 10 ** -11) * T2[i] ** 4 - 7602.24093)/287)
    p2[i] = p2[i] / 1000

#plt.plot(time_hrs, grain_size, 'o', label='data')
#plt.plot(time_hrs, fit_cosine, '-', label='My fit')
data = [[T2[0], u2[0], p2[0]],
        [T2[1], u2[1], p2[1]],
        [T2[2], u2[2], p2[2]]]
rows = ('', '', '') 
columns = ('T2 (K)', 'u2 (m/s)', 'p2 (kPa)') 
index = np.arange(len(columns)) + 0.3
colors = plt.cm.BuPu(np.linspace(0, 0.5, 3))
cell_text = [] 
for row in range(3): 
    #plt.plot(index, data[row], color=colors[row]) 
    y_offset = data[row] 
    cell_text.append([x for x in y_offset]) 

the_table = plt.table(cellText=cell_text, 
                      rowLabels=rows, 
                      rowColours=colors, 
                      colLabels=columns, 
                      loc='right') 

print(T2)
print(u2)
print(p2)

#plt.legend(loc='upper left')
#plt.xlabel('Time [hours]')
#plt.ylabel('Mean Grain Size [$\mu$m]')
# Out:
# [1100, 1200, 1300]
# [829.2753091826622, 678.9772716667328, 481.3713047741837]
# [76.38773243971053, 107.70875380610454, 148.28834589172493]
